# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_excel("../dataset/dataset.xlsx")

# %%
# Display basic information about the dataset
print("Dataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7075 entries, 0 to 7074
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       7074 non-null   object
#  1   generated  7075 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 110.7+ KB
# None

# %%
# Display the first few rows of the dataset
print("\nFirst Few Rows of the Dataset:")
print(df.head())
# Out:
# First Few Rows of the Dataset:
#                                                 text  generated
# 0  I just got back from your class, so I decided ...          0
# 1  It is 9:35 and I am beginning my stream of con...          0
# 2  Not only was the server down but it has taken ...          0
# 3  I am not exactly sure how this is supposed to ...          0
# 4  Well, here I am on Friday, September something...          0

# %%
# Summary statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#          generated
# count  7075.000000
# mean      0.999859
# std      31.358838
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max    2638.000000

# %%
# Distribution of the target variable
plt.figure(figsize=(8, 6))
sns.countplot(x="generated", data=df)
plt.title("Distribution of Target Variable")
plt.show()

# %%
# Word cloud for the text column
from wordcloud import WordCloud

# %%
# Convert the "text" column to strings
df["text"] = df["text"].astype(str)

# Generate word cloud
text_wordcloud = WordCloud(width=800, height=400, background_color="white").generate(" ".join(df["text"]))

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(text_wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud for Text Column")
plt.show()
